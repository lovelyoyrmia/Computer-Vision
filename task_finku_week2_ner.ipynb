# %% [markdown]
# <a href="https://colab.research.google.com/github/lovelyoyrmia/Computer-Vision/blob/master/task_finku_week2_ner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! gdown --id 1lldl9Qk5EoQhN5CbxFVxBAwH-edyOKs6
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1lldl9Qk5EoQhN5CbxFVxBAwH-edyOKs6
# To: /content/bca-cc-nertag 17-02-2022.xlsx
# 100% 993k/993k [00:00<00:00, 123MB/s]

# %%
import pandas as pd

# %%
df = pd.read_excel('bca-cc-nertag 17-02-2022.xlsx')

# %%
df.head()
# Out:
#    Unnamed: 0  token_0 BIO_tag_0
# 0           0      ---       ---
# 1           1  netflix  b-vendor
# 2           2                  O
# 3           3      com         O
# 4           4                  O

# %%
del df['Unnamed: 0']

# %%
df.shape
# Out:
# (62660, 2)

# %%
df.isnull().sum()
# Out:
# token_0         0
# BIO_tag_0    1215
# dtype: int64

# %%
df_copy = df.copy()

# %%
df_copy.head(20)
# Out:
#     token_0   BIO_tag_0
# 0       ---         ---
# 1   netflix    b-vendor
# 2                     O
# 3       com           O
# 4                     O
# 5       los  b-location
# 6                     O
# 7     gatos  e-location
# 8                     O
# 9        sg           O
# 10      ---         ---
# 11  cicilan           O
# 12                    O
# 13      bca    b-vendor
# 14                    O
# 15       ke           O
# 16                    O
# 17       09           O
# 18                    O
# 19     dari           O

# %%
listt = []
char = []
for i in df_copy.index:
  # if len(df_copy['token_0'][i]) < 2 and not df_copy['token_0'][i].isdigit():
  #   df_copy['BIO_tag_0'][i] = 'O'
  #   char.append([df_copy['token_0'][i], df_copy['BIO_tag_0'][i], i])
  if df_copy['token_0'][i] == 'iqos':
    if df_copy['token_0'][i - 1] == '---':      
      df_copy['BIO_tag_0'][i] = 'e-vendor'
      listt.append([df_copy['token_0'][i], df_copy['BIO_tag_0'][i], i])
    # elif df_copy['token_0'][i - 2] == 'kopi':
    #   df_copy['BIO_tag_0'][i] = 'i-vendor'
    #   listt.append([df_copy['token_0'][i], df_copy['BIO_tag_0'][i], i])
    else:
      df_copy['BIO_tag_0'][i] = 'e-vendor'
      listt.append([df_copy['token_0'][i], df_copy['BIO_tag_0'][i], i])
    # elif df_copy['token_0'][i + 1] == '&' and df_copy['token_0'][i + 2] == 'm':
    #   df_copy['BIO_tag_0'][i] = 'b-vendor'
    #   listt.append([df_copy['token_0'][i], df_copy['BIO_tag_0'][i], i])

# %%
listt = []
char = []
for i in df_copy.index:
  # if len(df_copy['token_0'][i]) < 2 and not df_copy['token_0'][i].isdigit():
  #   df_copy['BIO_tag_0'][i] = 'O'
  #   char.append([df_copy['token_0'][i], df_copy['BIO_tag_0'][i], i])
  if df_copy['token_0'][i] == 'fitness':
    df_copy['BIO_tag_0'][i] = 'e-vendor'
    listt.append([df_copy['token_0'][i], df_copy['BIO_tag_0'][i], i])

# %%
listt
# Out:
# [['fitness', 'e-vendor', 54303], ['fitness', 'e-vendor', 54321]]

# %%
null_values = []

bool_series = pd.isnull(df_copy['BIO_tag_0'])

null_value = df_copy[bool_series]

for i in null_value.index:
  null_values.append([null_value['token_0'][i], i])
  # print(null_value['token_0'][i])

# %%
len(null_values)
# Out:
# 994

# %%
null_values
# Out:
# [['sports', 14633],
#  ['super', 14751],
#  ['grain', 14753],
#  ['mal', 14777],
#  ['kapuk', 14791],
#  ['mtra', 14819],
#  ['kmyrn', 14821],
#  ['sunter', 14947],
#  ['resto', 14957],
#  ['snm', 14965],
#  ['dn', 15005],
#  ['lw', 15009],
#  ['dn', 15073],
#  ['ternak', 15227],
#  ['sentryskyvpn', 15591],
#  ['universitas', 15761],
#  ['mi', 15965],
#  ['summ', 15969],
#  ['st', 15983],
#  ['motowork', 15985],
#  ['pelonggarn', 16043],
#  ['fin', 16065],
#  ['fisik', 16091],
#  ['sport', 16093],
#  ['fisik', 16109],
#  ['sport', 16111],
#  ['pahlawan', 16163],
#  ['qzs', 16275],
#  ['pet', 16277],
#  ['station', 16279],
#  ['cfd', 16497],
#  ['vgtbabs', 16729],
#  ['lbx', 16747],
#  ['fs', 16751],
#  ['grma', 16769],
#  ['prsbcabs', 16787],
#  ['rzd', 16801],
#  ['blhena', 16823],
#  ['fhbwqatr', 16841],
#  ['uhpa', 16857],
#  ['ufkqa', 16877],
#  ['beccb', 17067],
#  ['bdf', 17145],
#  ['edd', 17393],
#  ['compli', 17529],
#  ['awal', 17559],
#  ['bros', 17561],
# ...

# %%
len(char)
# Out:
# 0

# %%
df_copy.isnull().sum()
# Out:
# token_0        0
# BIO_tag_0    994
# dtype: int64

# %%
df_copy.to_excel('bca-cc-nertag 17-02-2022.xlsx')
